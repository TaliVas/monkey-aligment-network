# %%
import scipy.io
import pandas as pd
import numpy as np
import os

# Directory containing the .mat files
files_dir = 'data_matlab/thina'
# List all .mat files in the directory
mat_files = [f for f in os.listdir(files_dir) if f.endswith('.mat')]
print(f"Found {len(mat_files)} .mat files in the directory.")
sorted_files = sorted(
    [f for f in os.listdir(files_dir) if f.endswith('.mat')],
    key=lambda x: int(''.join(filter(str.isdigit, x))))
# Initialize an empty list to store individual trial DataFrames
all_trials_df = []

# Columns for the trial data
types_1 = ['Control', 'HFS','Washout']
types_2 =['Control', 'HFS','Washout','Birst']
columns = ['time_milisecond', 'x', 'y', 'z','velocity']
additional_columns = ['move_time', 'end_time', 'update_time', 'start_turning', 'end_turning', 'id_target', 'id_update']

# Function to process each file and return a DataFrame
def process_mat_file(file_path, total_trials):
    # Load the .mat file
    mat_data = scipy.io.loadmat(file_path)
    print(f"Processing file: {file_path}")
    file_name = os.path.basename(file_path).replace('.mat', '')
    # Extract Update Trials
    handposU = mat_data['handposU']
    Cue2GoU = mat_data['Cue2GoU']
    Go2U = mat_data['Go2U']
    RTu = mat_data['RTu']
    MTu = mat_data['MTu']
    updTime = mat_data['updTime']
    updPause = mat_data['updPause']


    # Extract Non-Update Trials
    handpos = mat_data['handpos']
    Cue2Go = mat_data['Cue2Go']
    RT = mat_data['RT']
    MT = mat_data['MT']
    trials_in_this_file = 0


    # Initialize an empty list to store individual trial DataFrames for this file
    trial_dfs = []
    if handposU.shape[0] == 3:
        types = types_1
    if handposU.shape[0] == 4:
        types = types_2

     # Iterate over each type of control update trial

    for type_ind in range(len(types)):
        # Iterate over each control update trial
        num_trials_type =(handposU[type_ind][0].shape)[1]
        print(f"Processing Update {types[type_ind]} trials: {num_trials_type} trials found.")
        for i in range(num_trials_type):
            trial_data = handposU[type_ind, 0][0][i][:]
            trial_df = pd.DataFrame(trial_data, columns=columns)
            # Get the additional values for the current trial
            additional_values = handposU[type_ind, 0][1][i][0]
            # Create a dictionary of the additional values, repeating each value for the length of the trial DataFrame
            additional_data = {col_name: [additional_values[col_index]] * len(trial_df) for col_index, col_name in enumerate(additional_columns)}

            # Assign these values to the trial DataFrame
            trial_df = trial_df.assign(**additional_data)

            trial_df['id'] = total_trials + trials_in_this_file + 1 # Adjusting the trial ID to continue sequentially
            trial_df['type'] = 'Control'
            trial_df['file_name'] = file_name
            trial_df['trial_number_in_file'] = trials_in_this_file + 1
            trial_df['Cue2GoU'] = Cue2GoU[type_ind][0][0][i]
            trial_df['Go2U'] = Go2U[type_ind][0][0][i]
            trial_df['go_time'] = trial_df['time_milisecond'].iloc[0] + trial_df['Cue2GoU']
            trial_df['cue_time'] = trial_df['time_milisecond'].iloc[0]
            trial_df['MT'] = np.nan
            trial_df['MTu'] = MTu[type_ind][0][0][i]
            trial_df['RT'] = np.nan
            trial_df['RTu'] = RTu[type_ind][0][0][i]
            trial_df['updTime'] = updTime[type_ind][0][0][i]
            trial_df['updPause'] = updPause[type_ind][0][0][i]
            trial_dfs.append(trial_df)
            trials_in_this_file += 1

    for type_ind in range(len(types)):
        # Iterate over non-update trials
        num_trials_type =(handpos[type_ind][0].shape)[1]
        print(f"Processing Non-Update {types[type_ind]} trials: {num_trials_type} trials found.")
        for i in range(num_trials_type):
            trial_data = handpos[type_ind, 0][0][i][:]
            trial_df = pd.DataFrame(trial_data, columns=columns)

            # Get the additional values for the current trial
            additional_values = handpos[type_ind, 0][1][i][0]

            # Create a dictionary of the additional values, repeating each value for the length of the trial DataFrame
            additional_data = {col_name: [additional_values[col_index]] * len(trial_df) for col_index, col_name in enumerate(additional_columns)}

            # Assign these values to the trial DataFrame
            trial_df = trial_df.assign(**additional_data)

            trial_df['id'] = total_trials + trials_in_this_file + 1  # Adjusting the trial ID to continue sequentially
            trial_df['type'] = types[type_ind]
            trial_df['file_name'] = file_name
            trial_df['trial_number_in_file'] = trials_in_this_file + 1
            trial_df['Cue2Go'] = Cue2Go[type_ind][0][0][i]
            trial_df['Go2U'] = np.nan
            trial_df['go_time'] = trial_df['time_milisecond'].iloc[0] + trial_df['Cue2Go']
            trial_df['cue_time'] = trial_df['time_milisecond'].iloc[0]
            trial_df['MT'] = MT[type_ind][0][0][i]
            trial_df['MTu'] = np.nan
            trial_df['RT'] = RT[type_ind][0][0][i]
            trial_df['RTu'] = np.nan
            trial_df['updTime'] = np.nan
            trial_df['updPause'] = np.nan
            trial_dfs.append(trial_df)
            trials_in_this_file += 1


    print(f"Total trials in this file: {trials_in_this_file}")
    # Concatenate all trial DataFrames for this file into one DataFrame
    concatenated_df = pd.concat(trial_dfs, ignore_index=True)
    concatenated_df['turning_point'] = np.mean(concatenated_df[['start_turning', 'end_turning']], axis=1)

    return concatenated_df, total_trials + trials_in_this_file


# Initialize a variable to keep track of the total number of trials across all files
total_trials = 0

# Process each file and concatenate the results
for day_index, file in enumerate(sorted_files):
    total_trials_file = 0
    total_trials_file_u = 0
    print(f"Processing file {day_index+1}/{len(sorted_files)}: {file}")
    file_path = os.path.join(files_dir, file)
    file_df, total_trials = process_mat_file(file_path, total_trials)
    file_df['recording_day'] = day_index+1
    print(f"Processed {file}: {file_df['id'].nunique()} trials")
    all_trials_df.append(file_df)

# Concatenate all files' DataFrames into one big DataFrame
final_df = pd.concat(all_trials_df, ignore_index=True)
# Out:
# Found 20 .mat files in the directory.
# Processing file 1/20: t010123_v2.mat
# Processing file: /Users/avitalvasiliev/Documents/GitHub/TaggingV2Nirvik/ThinaData2/t010123_v2.mat
# Processing Update Control trials: 57 trials found.
# Processing Update HFS trials: 27 trials found.
# Processing Update Washout trials: 36 trials found.
# Processing Update Birst trials: 0 trials found.
# Processing Non-Update Control trials: 244 trials found.
# Processing Non-Update HFS trials: 148 trials found.
# Processing Non-Update Washout trials: 134 trials found.
# Processing Non-Update Birst trials: 0 trials found.
# Total trials in this file: 646
# Processed t010123_v2.mat: 646 trials
# Processing file 2/20: t011222_v2.mat
# Processing file: /Users/avitalvasiliev/Documents/GitHub/TaggingV2Nirvik/ThinaData2/t011222_v2.mat
# Processing Update Control trials: 78 trials found.
# Processing Update HFS trials: 47 trials found.
# Processing Update Washout trials: 35 trials found.
# Processing Update Birst trials: 0 trials found.
# Processing Non-Update Control trials: 387 trials found.
# Processing Non-Update HFS trials: 251 trials found.
# Processing Non-Update Washout trials: 140 trials found.
# Processing Non-Update Birst trials: 0 trials found.
# Total trials in this file: 938
# Processed t011222_v2.mat: 938 trials
# Processing file 3/20: t020123_v2.mat
# Processing file: /Users/avitalvasiliev/Documents/GitHub/TaggingV2Nirvik/ThinaData2/t020123_v2.mat
# Processing Update Control trials: 76 trials found.
# Processing Update HFS trials: 32 trials found.
# Processing Update Washout trials: 50 trials found.
# Processing Update Birst trials: 0 trials found.
# Processing Non-Update Control trials: 325 trials found.
# Processing Non-Update HFS trials: 196 trials found.
# Processing Non-Update Washout trials: 209 trials found.
# Processing Non-Update Birst trials: 0 trials found.
# Total trials in this file: 888
# Processed t020123_v2.mat: 888 trials
# Processing file 4/20: t030123_v2.mat
# Processing file: /Users/avitalvasiliev/Documents/GitHub/TaggingV2Nirvik/ThinaData2/t030123_v2.mat
# Processing Update Control trials: 72 trials found.
# Processing Update HFS trials: 43 trials found.
# Processing Update Washout trials: 43 trials found.
# Processing Update Birst trials: 0 trials found.
# Processing Non-Update Control trials: 331 trials found.
# Processing Non-Update HFS trials: 198 trials found.
# Processing Non-Update Washout trials: 211 trials found.
# Processing Non-Update Birst trials: 0 trials found.
# Total trials in this file: 898
# Processed t030123_v2.mat: 898 trials
# Processing file 5/20: t040123_v2.mat
# Processing file: /Users/avitalvasiliev/Documents/GitHub/TaggingV2Nirvik/ThinaData2/t040123_v2.mat
# Processing Update Control trials: 73 trials found.
# Processing Update HFS trials: 45 trials found.
# Processing Update Washout trials: 41 trials found.
# Processing Update Birst trials: 0 trials found.
# Processing Non-Update Control trials: 336 trials found.
# Processing Non-Update HFS trials: 192 trials found.
# Processing Non-Update Washout trials: 209 trials found.
# Processing Non-Update Birst trials: 0 trials found.
# Total trials in this file: 896
# Processed t040123_v2.mat: 896 trials
# Processing file 6/20: t041222_v2.mat
# Processing file: /Users/avitalvasiliev/Documents/GitHub/TaggingV2Nirvik/ThinaData2/t041222_v2.mat
# Processing Update Control trials: 91 trials found.
# Processing Update HFS trials: 0 trials found.
# Processing Update Washout trials: 0 trials found.
# Processing Update Birst trials: 0 trials found.
# Processing Non-Update Control trials: 430 trials found.
# Processing Non-Update HFS trials: 0 trials found.
# Processing Non-Update Washout trials: 0 trials found.
# Processing Non-Update Birst trials: 0 trials found.
# Total trials in this file: 521
# Processed t041222_v2.mat: 521 trials
# Processing file 7/20: t050123_v2.mat
# Processing file: /Users/avitalvasiliev/Documents/GitHub/TaggingV2Nirvik/ThinaData2/t050123_v2.mat
# Processing Update Control trials: 81 trials found.
# Processing Update HFS trials: 38 trials found.
# Processing Update Washout trials: 42 trials found.
# Processing Update Birst trials: 0 trials found.
# Processing Non-Update Control trials: 340 trials found.
# Processing Non-Update HFS trials: 203 trials found.
# Processing Non-Update Washout trials: 197 trials found.
# Processing Non-Update Birst trials: 0 trials found.
# Total trials in this file: 901
# Processed t050123_v2.mat: 901 trials
# Processing file 8/20: t080123_v2.mat
# Processing file: /Users/avitalvasiliev/Documents/GitHub/TaggingV2Nirvik/ThinaData2/t080123_v2.mat
# Processing Update Control trials: 71 trials found.
# Processing Update HFS trials: 38 trials found.
# Processing Update Washout trials: 52 trials found.
# Processing Update Birst trials: 0 trials found.
# Processing Non-Update Control trials: 329 trials found.
# Processing Non-Update HFS trials: 200 trials found.
# Processing Non-Update Washout trials: 207 trials found.
# Processing Non-Update Birst trials: 0 trials found.
# Total trials in this file: 897
# Processed t080123_v2.mat: 897 trials
# Processing file 9/20: t081222_v2.mat
# Processing file: /Users/avitalvasiliev/Documents/GitHub/TaggingV2Nirvik/ThinaData2/t081222_v2.mat
# Processing Update Control trials: 81 trials found.
# Processing Update HFS trials: 29 trials found.
# Processing Update Washout trials: 21 trials found.
# Processing Update Birst trials: 0 trials found.
# Processing Non-Update Control trials: 359 trials found.
# Processing Non-Update HFS trials: 147 trials found.
# Processing Non-Update Washout trials: 89 trials found.
# Processing Non-Update Birst trials: 0 trials found.
# Total trials in this file: 726
# Processed t081222_v2.mat: 726 trials
# Processing file 10/20: t111222_v2.mat
# Processing file: /Users/avitalvasiliev/Documents/GitHub/TaggingV2Nirvik/ThinaData2/t111222_v2.mat
# Processing Update Control trials: 40 trials found.
# Processing Update HFS trials: 17 trials found.
# Processing Update Washout trials: 20 trials found.
# Processing Update Birst trials: 0 trials found.
# Processing Non-Update Control trials: 231 trials found.
# Processing Non-Update HFS trials: 95 trials found.
# Processing Non-Update Washout trials: 90 trials found.
# Processing Non-Update Birst trials: 0 trials found.
# Total trials in this file: 493
# Processed t111222_v2.mat: 493 trials
# Processing file 11/20: t121222_v2.mat
# Processing file: /Users/avitalvasiliev/Documents/GitHub/TaggingV2Nirvik/ThinaData2/t121222_v2.mat
# Processing Update Control trials: 77 trials found.
# Processing Update HFS trials: 35 trials found.
# Processing Update Washout trials: 22 trials found.
# Processing Update Birst trials: 0 trials found.
# Processing Non-Update Control trials: 359 trials found.
# Processing Non-Update HFS trials: 195 trials found.
# Processing Non-Update Washout trials: 99 trials found.
# Processing Non-Update Birst trials: 0 trials found.
# Total trials in this file: 787
# Processed t121222_v2.mat: 787 trials
# Processing file 12/20: t251222_v2.mat
# Processing file: /Users/avitalvasiliev/Documents/GitHub/TaggingV2Nirvik/ThinaData2/t251222_v2.mat
# Processing Update Control trials: 28 trials found.
# Processing Update HFS trials: 7 trials found.
# Processing Update Washout trials: 7 trials found.
# Processing Update Birst trials: 0 trials found.
# Processing Non-Update Control trials: 120 trials found.
# Processing Non-Update HFS trials: 41 trials found.
# Processing Non-Update Washout trials: 32 trials found.
# Processing Non-Update Birst trials: 0 trials found.
# Total trials in this file: 235
# Processed t251222_v2.mat: 235 trials
# Processing file 13/20: t261222_v2.mat
# Processing file: /Users/avitalvasiliev/Documents/GitHub/TaggingV2Nirvik/ThinaData2/t261222_v2.mat
# Processing Update Control trials: 40 trials found.
# Processing Update HFS trials: 24 trials found.
# Processing Update Washout trials: 15 trials found.
# Processing Update Birst trials: 0 trials found.
# Processing Non-Update Control trials: 215 trials found.
# Processing Non-Update HFS trials: 134 trials found.
# Processing Non-Update Washout trials: 69 trials found.
# Processing Non-Update Birst trials: 0 trials found.
# Total trials in this file: 497
# Processed t261222_v2.mat: 497 trials
# Processing file 14/20: t271122_v2.mat
# Processing file: /Users/avitalvasiliev/Documents/GitHub/TaggingV2Nirvik/ThinaData2/t271122_v2.mat
# Processing Update Control trials: 53 trials found.
# Processing Update HFS trials: 31 trials found.
# Processing Update Washout trials: 19 trials found.
# Processing Update Birst trials: 0 trials found.
# Processing Non-Update Control trials: 235 trials found.
# Processing Non-Update HFS trials: 145 trials found.
# Processing Non-Update Washout trials: 86 trials found.
# Processing Non-Update Birst trials: 0 trials found.
# Total trials in this file: 569
# Processed t271122_v2.mat: 569 trials
# Processing file 15/20: t271222_v2.mat
# Processing file: /Users/avitalvasiliev/Documents/GitHub/TaggingV2Nirvik/ThinaData2/t271222_v2.mat
# Processing Update Control trials: 39 trials found.
# Processing Update HFS trials: 25 trials found.
# Processing Update Washout trials: 15 trials found.
# Processing Update Birst trials: 0 trials found.
# Processing Non-Update Control trials: 196 trials found.
# Processing Non-Update HFS trials: 92 trials found.
# Processing Non-Update Washout trials: 59 trials found.
# Processing Non-Update Birst trials: 0 trials found.
# Total trials in this file: 426
# Processed t271222_v2.mat: 426 trials
# Processing file 16/20: t281122_v2.mat
# Processing file: /Users/avitalvasiliev/Documents/GitHub/TaggingV2Nirvik/ThinaData2/t281122_v2.mat
# Processing Update Control trials: 89 trials found.
# Processing Update HFS trials: 44 trials found.
# Processing Update Washout trials: 28 trials found.
# Processing Update Birst trials: 0 trials found.
# Processing Non-Update Control trials: 388 trials found.
# Processing Non-Update HFS trials: 222 trials found.
# Processing Non-Update Washout trials: 118 trials found.
# Processing Non-Update Birst trials: 0 trials found.
# Total trials in this file: 889
# Processed t281122_v2.mat: 889 trials
# Processing file 17/20: t281222_v2.mat
# Processing file: /Users/avitalvasiliev/Documents/GitHub/TaggingV2Nirvik/ThinaData2/t281222_v2.mat
# Processing Update Control trials: 36 trials found.
# Processing Update HFS trials: 14 trials found.
# Processing Update Washout trials: 18 trials found.
# Processing Update Birst trials: 0 trials found.
# Processing Non-Update Control trials: 213 trials found.
# Processing Non-Update HFS trials: 76 trials found.
# Processing Non-Update Washout trials: 82 trials found.
# Processing Non-Update Birst trials: 0 trials found.
# Total trials in this file: 439
# Processed t281222_v2.mat: 439 trials
# Processing file 18/20: t291122_v2.mat
# Processing file: /Users/avitalvasiliev/Documents/GitHub/TaggingV2Nirvik/ThinaData2/t291122_v2.mat
# Processing Update Control trials: 85 trials found.
# Processing Update HFS trials: 52 trials found.
# Processing Update Washout trials: 26 trials found.
# Processing Update Birst trials: 0 trials found.
# Processing Non-Update Control trials: 393 trials found.
# Processing Non-Update HFS trials: 245 trials found.
# Processing Non-Update Washout trials: 124 trials found.
# Processing Non-Update Birst trials: 0 trials found.
# Total trials in this file: 925
# Processed t291122_v2.mat: 925 trials
# Processing file 19/20: t291222_v2.mat
# Processing file: /Users/avitalvasiliev/Documents/GitHub/TaggingV2Nirvik/ThinaData2/t291222_v2.mat
# Processing Update Control trials: 42 trials found.
# Processing Update HFS trials: 31 trials found.
# Processing Update Washout trials: 17 trials found.
# Processing Update Birst trials: 0 trials found.
# Processing Non-Update Control trials: 197 trials found.
# Processing Non-Update HFS trials: 130 trials found.
# Processing Non-Update Washout trials: 81 trials found.
# Processing Non-Update Birst trials: 0 trials found.
# Total trials in this file: 498
# Processed t291222_v2.mat: 498 trials
# Processing file 20/20: t301122_v2.mat
# Processing file: /Users/avitalvasiliev/Documents/GitHub/TaggingV2Nirvik/ThinaData2/t301122_v2.mat
# Processing Update Control trials: 82 trials found.
# Processing Update HFS trials: 45 trials found.
# Processing Update Washout trials: 31 trials found.
# Processing Update Birst trials: 0 trials found.
# Processing Non-Update Control trials: 384 trials found.
# Processing Non-Update HFS trials: 251 trials found.
# Processing Non-Update Washout trials: 157 trials found.
# Processing Non-Update Birst trials: 0 trials found.
# Total trials in this file: 950
# Processed t301122_v2.mat: 950 trials

# %%
final_df.to_csv(RawData/'FinalDfThina.csv', index=False)
